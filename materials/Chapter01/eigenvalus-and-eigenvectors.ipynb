# %%
import numpy as np

# %%
# %run ../functions.py

# %%
temp = generate_numbers(21, 9, 0)
temp
# Out:
# [11, 8, 9, 3, 20, 15, 12, 10, 13]

# %%
sample = make_shape(temp)

# %%
A = np.array(sample)
A
# Out:
# array([[11,  8,  9],
#        [ 3, 20, 15],
#        [12, 10, 13]])

# %%
# linear algebra, Compute the eigenvalues and right eigenvectors of a square array
v, B = np.linalg.eig(A)
v, B
# Out:
# (array([34.48957297,  7.85724873,  1.6531783 ]),
#  array([[-0.45216717, -0.39904546, -0.23584566],
#         [-0.68499402,  0.75007961, -0.59169883],
#         [-0.57125129, -0.52739292,  0.77088866]]))

# %%
# Extract a diagonal or construct a diagonal array.
D = np.diag(v)
D
# Out:
# array([[34.48957297,  0.        ,  0.        ],
#        [ 0.        ,  7.85724873,  0.        ],
#        [ 0.        ,  0.        ,  1.6531783 ]])

# %%
A_reconstructed = np.dot(B, np.dot(D, np.linalg.inv(B)))
A_reconstructed
# Out:
# array([[11.,  8.,  9.],
#        [ 3., 20., 15.],
#        [12., 10., 13.]])

# %%
# B[0]    # array([ 0.73271846, -0.65131465,  0.19726352])

# %%
D2 = np.diag(B[0])
D2
# Out:
# array([[-0.45216717,  0.        ,  0.        ],
#        [ 0.        , -0.39904546,  0.        ],
#        [ 0.        ,  0.        , -0.23584566]])

# %%
i = 0  
lambda0 = v[i]
lambda0
# Out:
# 34.489572974162755

# %%
B
# Out:
# array([[-0.45216717, -0.39904546, -0.23584566],
#        [-0.68499402,  0.75007961, -0.59169883],
#        [-0.57125129, -0.52739292,  0.77088866]])

# %%
x0 = B[:, i]    # get the first column of B
x0
# Out:
# array([-0.45216717, -0.68499402, -0.57125129])

# %%
np.linalg.norm(x0)
# Out:
# 0.9999999999999999

# %%
x1 = B[:, 1]    # second column
x1
# Out:
# array([-0.39904546,  0.75007961, -0.52739292])

# %%
x2 = B[:, 2]   
x2
# Out:
# array([-0.23584566, -0.59169883,  0.77088866])

# %%
np.linalg.norm(x1)
# Out:
# 0.9999999999999999

# %%
x2 = B[i, :]        # row 1st
# x2 = B[1, :]    # row 2nd
x2
# Out:
# array([-0.45216717, -0.39904546, -0.23584566])

# %%
np.linalg.norm(x2)
# Out:
# 0.6475458325397574

# %%
A
# Out:
# array([[11,  8,  9],
#        [ 3, 20, 15],
#        [12, 10, 13]])

# %%
lhs = A @ x0    # matmul
lhs
# Out:
# array([-15.59505269, -23.62515133, -19.70221308])

# %%
lambda0
# Out:
# 34.489572974162755

# %%
rhs = lambda0*x0
rhs
# Out:
# array([-15.59505269, -23.62515133, -19.70221308])

# %%
np.linalg.norm(lhs - rhs)
# Out:
# 2.2539441496237913e-14
