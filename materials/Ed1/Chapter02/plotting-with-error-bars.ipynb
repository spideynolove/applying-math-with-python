# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %run ../../functions.py

# %%
measurement_id = np.arange(1, 11)
# measurements = np.array([2.3, 1.9, 4.4, 1.5, 3.0, 3.3, 2.9, 2.6, 4.1, 3.6])

# %%
measurements = np.array(make_shape(generate_numbers(13, 10, 0, 'float'), (10,)))
measurements
# Out:
# array([ 7.9, 11.8,  1.5,  6.8,  3.9,  2.7,  5.8,  0.1,  2.4,  9.2])

# %%
# err = np.array([0.1]*10)
err = np.array(make_shape(generate_numbers(13, 10, 0, 'float'), (10,)))
err
# Out:
# array([ 9. , 10.8,  3.4,  6.9, 10.2,  1.8,  6. ,  8.4,  1.4,  5.2])

# %%
fig, ax = plt.subplots()
ax.errorbar(measurement_id, measurements, yerr=err, fmt="kx", capsize=2.0)
ax.set_title("Plot of measurements and their estimated error")
ax.set_xlabel("Measurement ID")
ax.set_ylabel("Measurement (cm)")
ax.set_xticks(measurement_id)
plt.show()
