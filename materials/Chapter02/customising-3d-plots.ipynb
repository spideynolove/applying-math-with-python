# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %%
t = np.linspace(-5, 5, 100)
t.shape
# Out:
# (100,)

# %%
x, y = np.meshgrid(t, t)
x.shape, y.shape
# Out:
# ((100, 100), (100, 100))

# %%
z = np.exp(-((x-2.)**2 + (y-3.)**2)/4) - np.exp(-((x+3.)**2 + (y+2)**2)/3)
z
# Out:
# array([[-1.31237287e-02, -1.49648043e-02, -1.69484801e-02, ...,
#          1.58180303e-08,  1.37201903e-08,  1.18340701e-08],
#        [-1.60072402e-02, -1.82528322e-02, -2.06723560e-02, ...,
#          2.36544078e-08,  2.05113061e-08,  1.76880971e-08],
#        [-1.93919551e-02, -2.21123752e-02, -2.50435050e-02, ...,
#          3.51872919e-08,  3.05044484e-08,  2.63014765e-08],
#        ...,
#        [ 2.07874380e-06,  2.96786467e-06,  4.21152460e-06, ...,
#          6.29537105e-02,  5.45183222e-02,  4.69729752e-02],
#        [ 1.90854906e-06,  2.72053713e-06,  3.85562727e-06, ...,
#          5.73424899e-02,  4.96589686e-02,  4.27861572e-02],
#        [ 1.73909116e-06,  2.47627415e-06,  3.50636600e-06, ...,
#          5.19656302e-02,  4.50025732e-02,  3.87742078e-02]])

# %%
fig = plt.figure()
ax = fig.add_subplot(projection="3d", proj_type="ortho")
ax.plot_surface(x, y, z, cmap="gray", vmin=-1.2, vmax=1.2)
ax.set_title("Customized 3D surface plot")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
plt.show()
